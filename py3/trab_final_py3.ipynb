# %%
from __future__ import division

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn.cross_validation import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
from sklearn.pipeline import Pipeline
from sklearn.svm import OneClassSVM
# Out:
# /home/victorgarritano/miniconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
df_train = pd.read_csv('new_train.csv')

# %%
names = df_train.columns.values.tolist()[:-1]

# %%
df_test = pd.read_csv('test.csv', names=names)

# %%
# remove constant columns
remove = []
for col in df_train.columns:
    if df_train[col].std() == 0:
        remove.append(col)

df_train.drop(remove, axis=1, inplace=True)
df_test.drop(remove, axis=1, inplace=True)

# %%
# remove duplicated columns
remove = []
c = df_train.columns
for i in range(len(c)-1):
    v = df_train[c[i]].values
    for j in range(i+1,len(c)):
        if np.array_equal(v,df_train[c[j]].values):
            remove.append(c[j])
df_train.drop(remove, axis=1, inplace=True)
df_test.drop(remove, axis=1, inplace=True)

# %%
y_train = df_train['TARGET'].values
X_train = df_train.drop(['TARGET'], axis=1).values

X_test = df_test.values

# length of dataset
len_train = len(X_train)
len_test  = len(X_test)

# %%
print (len_train, len_test)
# Out:
# 60020 16000

# %%
# classifier
clf = xgb.XGBClassifier(missing=np.nan, max_depth=5,
                        n_estimators=350, learning_rate=0.03, 
                        nthread=-1, subsample=0.95, colsample_bytree=0.85, seed=4242)

X_fit, X_eval, y_fit, y_eval= train_test_split(X_train, y_train, test_size=0.3)

# %%
# fitting
clf.fit(X_train, y_train, early_stopping_rounds=20, eval_metric="auc", eval_set=[(X_eval, y_eval)])
# Out:
# [0]	validation_0-auc:0.818978
# Will train until validation_0-auc hasn't improved in 20 rounds.
# [1]	validation_0-auc:0.828184
# [2]	validation_0-auc:0.833406
# [3]	validation_0-auc:0.833371
# [4]	validation_0-auc:0.834036
# [5]	validation_0-auc:0.833722
# [6]	validation_0-auc:0.834198
# [7]	validation_0-auc:0.839992
# [8]	validation_0-auc:0.841152
# [9]	validation_0-auc:0.841298
# [10]	validation_0-auc:0.841235
# [11]	validation_0-auc:0.84277
# [12]	validation_0-auc:0.84268
# [13]	validation_0-auc:0.84435
# [14]	validation_0-auc:0.843755
# [15]	validation_0-auc:0.845637
# [16]	validation_0-auc:0.846405
# [17]	validation_0-auc:0.847229
# [18]	validation_0-auc:0.847426
# [19]	validation_0-auc:0.847847
# [20]	validation_0-auc:0.847999
# [21]	validation_0-auc:0.848085
# [22]	validation_0-auc:0.849025
# [23]	validation_0-auc:0.84947
# [24]	validation_0-auc:0.849518
# [25]	validation_0-auc:0.84974
# [26]	validation_0-auc:0.84975
# [27]	validation_0-auc:0.849513
# [28]	validation_0-auc:0.849626
# [29]	validation_0-auc:0.850056
# [30]	validation_0-auc:0.850277
# [31]	validation_0-auc:0.850901
# [32]	validation_0-auc:0.850639
# [33]	validation_0-auc:0.850362
# [34]	validation_0-auc:0.851071
# [35]	validation_0-auc:0.85109
# [36]	validation_0-auc:0.851491
# [37]	validation_0-auc:0.851786
# [38]	validation_0-auc:0.851818
# [39]	validation_0-auc:0.851916
# [40]	validation_0-auc:0.852163
# [41]	validation_0-auc:0.852435
# [42]	validation_0-auc:0.85314
# [43]	validation_0-auc:0.852797
# [44]	validation_0-auc:0.852763
# [45]	validation_0-auc:0.852982
# [46]	validation_0-auc:0.85313
# [47]	validation_0-auc:0.853216
# [48]	validation_0-auc:0.85333
# [49]	validation_0-auc:0.853732
# [50]	validation_0-auc:0.854108
# [51]	validation_0-auc:0.854449
# [52]	validation_0-auc:0.854972
# [53]	validation_0-auc:0.855095
# [54]	validation_0-auc:0.855141
# [55]	validation_0-auc:0.855466
# [56]	validation_0-auc:0.856112
# [57]	validation_0-auc:0.856586
# [58]	validation_0-auc:0.856806
# [59]	validation_0-auc:0.857049
# [60]	validation_0-auc:0.857039
# [61]	validation_0-auc:0.857416
# [62]	validation_0-auc:0.857828
# [63]	validation_0-auc:0.857739
# [64]	validation_0-auc:0.85786
# [65]	validation_0-auc:0.858027
# [66]	validation_0-auc:0.858113
# [67]	validation_0-auc:0.858392
# [68]	validation_0-auc:0.858486
# [69]	validation_0-auc:0.858621
# [70]	validation_0-auc:0.858514
# [71]	validation_0-auc:0.858817
# [72]	validation_0-auc:0.858909
# [73]	validation_0-auc:0.858873
# [74]	validation_0-auc:0.859043
# [75]	validation_0-auc:0.859533
# [76]	validation_0-auc:0.859779
# [77]	validation_0-auc:0.859795
# [78]	validation_0-auc:0.859864
# [79]	validation_0-auc:0.860016
# [80]	validation_0-auc:0.860225
# [81]	validation_0-auc:0.860319
# [82]	validation_0-auc:0.860629
# [83]	validation_0-auc:0.86073
# [84]	validation_0-auc:0.86097
# [85]	validation_0-auc:0.860974
# [86]	validation_0-auc:0.861159
# [87]	validation_0-auc:0.861587
# [88]	validation_0-auc:0.861938
# [89]	validation_0-auc:0.862224
# [90]	validation_0-auc:0.862437
# [91]	validation_0-auc:0.862659
# [92]	validation_0-auc:0.862669
# [93]	validation_0-auc:0.862775
# [94]	validation_0-auc:0.863239
# [95]	validation_0-auc:0.863387
# [96]	validation_0-auc:0.86358
# [97]	validation_0-auc:0.863554
# [98]	validation_0-auc:0.863593
# [99]	validation_0-auc:0.863928
# [100]	validation_0-auc:0.864099
# [101]	validation_0-auc:0.864114
# [102]	validation_0-auc:0.864613
# [103]	validation_0-auc:0.86479
# [104]	validation_0-auc:0.864891
# [105]	validation_0-auc:0.865169
# [106]	validation_0-auc:0.86548
# [107]	validation_0-auc:0.865796
# [108]	validation_0-auc:0.865951
# [109]	validation_0-auc:0.866098
# [110]	validation_0-auc:0.866278
# [111]	validation_0-auc:0.866371
# [112]	validation_0-auc:0.86662
# [113]	validation_0-auc:0.866889
# [114]	validation_0-auc:0.867171
# [115]	validation_0-auc:0.867242
# [116]	validation_0-auc:0.867334
# [117]	validation_0-auc:0.867533
# [118]	validation_0-auc:0.867672
# [119]	validation_0-auc:0.867808
# [120]	validation_0-auc:0.867854
# [121]	validation_0-auc:0.868051
# [122]	validation_0-auc:0.868224
# [123]	validation_0-auc:0.868435
# [124]	validation_0-auc:0.868555
# [125]	validation_0-auc:0.868757
# [126]	validation_0-auc:0.868728
# [127]	validation_0-auc:0.868857
# [128]	validation_0-auc:0.869093
# [129]	validation_0-auc:0.869296
# [130]	validation_0-auc:0.869298
# [131]	validation_0-auc:0.869416
# [132]	validation_0-auc:0.869634
# [133]	validation_0-auc:0.869761
# [134]	validation_0-auc:0.870051
# [135]	validation_0-auc:0.870237
# [136]	validation_0-auc:0.870489
# [137]	validation_0-auc:0.870679
# [138]	validation_0-auc:0.870912
# [139]	validation_0-auc:0.87104
# [140]	validation_0-auc:0.871145
# [141]	validation_0-auc:0.871189
# [142]	validation_0-auc:0.871507
# [143]	validation_0-auc:0.871643
# [144]	validation_0-auc:0.871704
# [145]	validation_0-auc:0.871778
# [146]	validation_0-auc:0.871927
# [147]	validation_0-auc:0.872226
# [148]	validation_0-auc:0.872423
# [149]	validation_0-auc:0.872506
# [150]	validation_0-auc:0.872548
# [151]	validation_0-auc:0.872751
# [152]	validation_0-auc:0.872946
# [153]	validation_0-auc:0.873074
# [154]	validation_0-auc:0.873086
# [155]	validation_0-auc:0.873227
# [156]	validation_0-auc:0.873414
# [157]	validation_0-auc:0.873568
# [158]	validation_0-auc:0.873692
# [159]	validation_0-auc:0.873772
# [160]	validation_0-auc:0.873841
# [161]	validation_0-auc:0.874101
# [162]	validation_0-auc:0.874163
# [163]	validation_0-auc:0.874211
# [164]	validation_0-auc:0.874364
# [165]	validation_0-auc:0.874428
# [166]	validation_0-auc:0.874504
# [167]	validation_0-auc:0.874655
# [168]	validation_0-auc:0.874772
# [169]	validation_0-auc:0.874863
# [170]	validation_0-auc:0.875016
# [171]	validation_0-auc:0.875094
# [172]	validation_0-auc:0.875163
# [173]	validation_0-auc:0.875215
# [174]	validation_0-auc:0.875309
# [175]	validation_0-auc:0.87549
# [176]	validation_0-auc:0.875611
# [177]	validation_0-auc:0.8757
# [178]	validation_0-auc:0.875769
# [179]	validation_0-auc:0.875823
# [180]	validation_0-auc:0.875824
# [181]	validation_0-auc:0.875895
# [182]	validation_0-auc:0.87603
# [183]	validation_0-auc:0.876086
# [184]	validation_0-auc:0.876256
# [185]	validation_0-auc:0.876313
# [186]	validation_0-auc:0.876424
# [187]	validation_0-auc:0.876564
# [188]	validation_0-auc:0.876629
# [189]	validation_0-auc:0.876691
# [190]	validation_0-auc:0.876755
# [191]	validation_0-auc:0.876849
# [192]	validation_0-auc:0.877053
# [193]	validation_0-auc:0.877175
# [194]	validation_0-auc:0.877186
# [195]	validation_0-auc:0.87726
# [196]	validation_0-auc:0.877401
# [197]	validation_0-auc:0.877595
# [198]	validation_0-auc:0.877656
# [199]	validation_0-auc:0.877912
# [200]	validation_0-auc:0.878036
# [201]	validation_0-auc:0.878193
# [202]	validation_0-auc:0.878266
# [203]	validation_0-auc:0.878426
# [204]	validation_0-auc:0.878533
# [205]	validation_0-auc:0.878727
# [206]	validation_0-auc:0.878781
# [207]	validation_0-auc:0.878885
# [208]	validation_0-auc:0.879167
# [209]	validation_0-auc:0.8793
# [210]	validation_0-auc:0.879434
# [211]	validation_0-auc:0.879469
# [212]	validation_0-auc:0.8796
# [213]	validation_0-auc:0.879761
# [214]	validation_0-auc:0.879851
# [215]	validation_0-auc:0.879961
# [216]	validation_0-auc:0.879993
# [217]	validation_0-auc:0.880211
# [218]	validation_0-auc:0.880393
# [219]	validation_0-auc:0.880428
# [220]	validation_0-auc:0.880657
# [221]	validation_0-auc:0.880728
# [222]	validation_0-auc:0.880947
# [223]	validation_0-auc:0.881098
# [224]	validation_0-auc:0.881169
# [225]	validation_0-auc:0.881319
# [226]	validation_0-auc:0.88138
# [227]	validation_0-auc:0.881443
# [228]	validation_0-auc:0.881491
# [229]	validation_0-auc:0.881665
# [230]	validation_0-auc:0.881721
# [231]	validation_0-auc:0.881832
# [232]	validation_0-auc:0.881881
# [233]	validation_0-auc:0.882104
# [234]	validation_0-auc:0.882145
# [235]	validation_0-auc:0.882216
# [236]	validation_0-auc:0.882267
# [237]	validation_0-auc:0.882462
# [238]	validation_0-auc:0.882634
# [239]	validation_0-auc:0.882696
# [240]	validation_0-auc:0.882748
# [241]	validation_0-auc:0.882799
# [242]	validation_0-auc:0.882869
# [243]	validation_0-auc:0.882892
# [244]	validation_0-auc:0.882933
# [245]	validation_0-auc:0.883032
# [246]	validation_0-auc:0.883089
# [247]	validation_0-auc:0.883286
# [248]	validation_0-auc:0.883338
# [249]	validation_0-auc:0.883577
# [250]	validation_0-auc:0.883647
# [251]	validation_0-auc:0.883686
# [252]	validation_0-auc:0.883749
# [253]	validation_0-auc:0.883777
# [254]	validation_0-auc:0.883798
# [255]	validation_0-auc:0.883946
# [256]	validation_0-auc:0.884075
# [257]	validation_0-auc:0.884169
# [258]	validation_0-auc:0.884257
# [259]	validation_0-auc:0.884311
# [260]	validation_0-auc:0.884328
# [261]	validation_0-auc:0.884345
# [262]	validation_0-auc:0.884373
# [263]	validation_0-auc:0.884464
# [264]	validation_0-auc:0.884507
# [265]	validation_0-auc:0.884692
# [266]	validation_0-auc:0.884715
# [267]	validation_0-auc:0.884762
# [268]	validation_0-auc:0.884841
# [269]	validation_0-auc:0.884873
# [270]	validation_0-auc:0.884894
# [271]	validation_0-auc:0.884902
# [272]	validation_0-auc:0.885075
# [273]	validation_0-auc:0.885256
# [274]	validation_0-auc:0.885318
# [275]	validation_0-auc:0.885344
# [276]	validation_0-auc:0.885359
# [277]	validation_0-auc:0.885494
# [278]	validation_0-auc:0.885692
# [279]	validation_0-auc:0.885715
# [280]	validation_0-auc:0.885783
# [281]	validation_0-auc:0.885861
# [282]	validation_0-auc:0.886056
# [283]	validation_0-auc:0.886243
# [284]	validation_0-auc:0.88638
# [285]	validation_0-auc:0.886416
# [286]	validation_0-auc:0.886511
# [287]	validation_0-auc:0.886646
# [288]	validation_0-auc:0.886725
# [289]	validation_0-auc:0.886732
# [290]	validation_0-auc:0.886749
# [291]	validation_0-auc:0.886727
# [292]	validation_0-auc:0.88676
# [293]	validation_0-auc:0.886799
# [294]	validation_0-auc:0.886922
# [295]	validation_0-auc:0.887014
# [296]	validation_0-auc:0.887052
# [297]	validation_0-auc:0.887308
# [298]	validation_0-auc:0.887365
# [299]	validation_0-auc:0.887415
# [300]	validation_0-auc:0.887513
# [301]	validation_0-auc:0.887695
# [302]	validation_0-auc:0.887806
# [303]	validation_0-auc:0.887844
# [304]	validation_0-auc:0.887873
# [305]	validation_0-auc:0.887961
# [306]	validation_0-auc:0.888061
# [307]	validation_0-auc:0.888101
# [308]	validation_0-auc:0.888224
# [309]	validation_0-auc:0.888264
# [310]	validation_0-auc:0.888432
# [311]	validation_0-auc:0.888625
# [312]	validation_0-auc:0.888669
# [313]	validation_0-auc:0.888699
# [314]	validation_0-auc:0.888717
# [315]	validation_0-auc:0.888775
# [316]	validation_0-auc:0.888797
# [317]	validation_0-auc:0.8888
# [318]	validation_0-auc:0.88883
# [319]	validation_0-auc:0.888868
# [320]	validation_0-auc:0.888901
# [321]	validation_0-auc:0.888915
# [322]	validation_0-auc:0.888959
# [323]	validation_0-auc:0.889138
# [324]	validation_0-auc:0.889336
# [325]	validation_0-auc:0.889321
# [326]	validation_0-auc:0.889387
# [327]	validation_0-auc:0.889526
# [328]	validation_0-auc:0.889559
# [329]	validation_0-auc:0.889716
# [330]	validation_0-auc:0.889747
# [331]	validation_0-auc:0.8898
# [332]	validation_0-auc:0.889874
# [333]	validation_0-auc:0.889906
# [334]	validation_0-auc:0.889949
# [335]	validation_0-auc:0.889973
# [336]	validation_0-auc:0.890029
# [337]	validation_0-auc:0.890158
# [338]	validation_0-auc:0.89017
# [339]	validation_0-auc:0.890219
# [340]	validation_0-auc:0.89027
# [341]	validation_0-auc:0.890325
# [342]	validation_0-auc:0.890504
# [343]	validation_0-auc:0.890652
# [344]	validation_0-auc:0.890675
# [345]	validation_0-auc:0.890687
# [346]	validation_0-auc:0.890711
# [347]	validation_0-auc:0.890753
# [348]	validation_0-auc:0.890767
# [349]	validation_0-auc:0.8908
# XGBClassifier(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.85,
#        gamma=0, learning_rate=0.03, max_delta_step=0, max_depth=5,
#        min_child_weight=1, missing=None, n_estimators=350, nthread=-1,
#        objective='binary:logistic', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=4242, silent=True, subsample=0.95)

# %%
print('Overall AUC:', roc_auc_score(y_train, clf.predict_proba(X_train)[:,1]))
# Out:
# Overall AUC: 0.888682817864

# %%
# predicting
y_pred= clf.predict_proba(X_test)[:,1]

# %%
submission = pd.DataFrame(data=y_pred)
submission.to_csv("submission.csv", index=False, header=None)

# %%
y_pred
# Out:
# array([ 0.01587451,  0.00440938,  0.02592113, ...,  0.02741839,
#         0.00851961,  0.03069277], dtype=float32)

# %%
y_pred.shape
# Out:
# (16000,)

# %%
submission
# Out:
#               0
# 0      0.015875
# 1      0.004409
# 2      0.025921
# 3      0.105370
# 4      0.084023
# 5      0.052264
# 6      0.002626
# 7      0.045652
# 8      0.005847
# 9      0.008421
# 10     0.009959
# 11     0.284330
# 12     0.005383
# 13     0.036960
# 14     0.158423
# 15     0.010165
# 16     0.092134
# 17     0.008407
# 18     0.017273
# 19     0.097251
# 20     0.033922
# 21     0.273750
# 22     0.000983
# 23     0.018019
# 24     0.161887
# 25     0.001143
# 26     0.002948
# 27     0.030693
# 28     0.012084
# 29     0.001453
# ...         ...
# 15970  0.002603
# 15971  0.011124
# 15972  0.028379
# 15973  0.064537
# 15974  0.309748
# 15975  0.049865
# 15976  0.028165
# 15977  0.009433
# 15978  0.030829
# 15979  0.003865
# 15980  0.008446
# 15981  0.228824
# 15982  0.050138
# 15983  0.008794
# 15984  0.027767
# 15985  0.017250
# 15986  0.003047
# 15987  0.238367
# 15988  0.010431
# 15989  0.017979
# 15990  0.008617
# 15991  0.038228
# 15992  0.008358
# 15993  0.009219
# 15994  0.003507
# 15995  0.012454
# 15996  0.019099
# 15997  0.027418
# 15998  0.008520
# 15999  0.030693
#
# [16000 rows x 1 columns]
